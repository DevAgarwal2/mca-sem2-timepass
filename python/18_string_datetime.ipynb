# %%
import datetimeprint("String methods:")s = "  Hello World  "print("Original: '{}'".format(s))print("Upper:", s.upper())print("Lower:", s.lower())print("Strip:", s.strip())print("Split:", s.split())print("Replace:", s.replace("World", "Python"))print("Find 'World':", s.find("World"))print("\nDate and time:")now = datetime.datetime.now()print("Current date/time:", now)print("Date:", now.date())print("Time:", now.time())print("Year:", now.year)print("Month:", now.month)print("Day:", now.day)today = datetime.date.today()print("\nToday's date:", today)from datetime import timedeltatomorrow = today + timedelta(days=1)print("Tomorrow:", tomorrow)delta = timedelta(days=5)past = today - deltaprint("5 days ago:", past)
