# %%
def is_kaprekar(n):    if n == 1:        return True    square = n * n    str_square = str(square)    length = len(str_square)    for i in range(1, length):        left = int(str_square[:i])        right = int(str_square[i:])        if right == 0:            continue        if left + right == n:            return True    return Falsenum = int(input("Enter a number: "))if is_kaprekar(num):    print("{} is a Kaprekar number.".format(num))else:    print("{} is not a Kaprekar number.".format(num))print("\nKaprekar numbers:")kaprekar_nums = []for n in range(1, 100):    if is_kaprekar(n):        kaprekar_nums.append(n)print(kaprekar_nums)
