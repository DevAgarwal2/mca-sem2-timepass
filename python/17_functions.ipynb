# %%
def greet(name):    return "Hello, " + name + "!"def add(a, b):    return a + bdef factorial(n):    if n <= 1:        return 1    return n * factorial(n - 1)print(greet("Python"))print("3 + 5 =", add(3, 5))print("5! =", factorial(5))x = 10def test_scope():    x = 20    print("Inside function:", x)print("\nGlobal x:", x)test_scope()print("After function:", x)def test_global():    global x    x = 30    print("Inside function (global):", x)test_global()print("After global:", x)print("\nBuilt-in functions:")nums = [3, 1, 4, 1, 5, 9]print("List:", nums)print("len:", len(nums))print("sum:", sum(nums))print("min:", min(nums))print("max:", max(nums))print("sorted:", sorted(nums))print("abs(-5):", abs(-5))print("pow(2,3):", pow(2, 3))
