# %%
import sysimport mathdef areaTriangle(a, b, c):    s = (a + b + c) / 2    area = math.sqrt(s * (s - a) * (s - b) * (s - c))    return areadef main():    if len(sys.argv) != 4:        print("Usage: python triangle.py <side1> <side2> <side3>")        a = float(input("Enter side 1: "))        b = float(input("Enter side 2: "))        c = float(input("Enter side 3: "))    else:        a = float(sys.argv[1])        b = float(sys.argv[2])        c = float(sys.argv[3])    assert a + b > c, "Sum of side1 and side2 must be greater than side3"    assert a + c > b, "Sum of side1 and side3 must be greater than side2"    assert b + c > a, "Sum of side2 and side3 must be greater than side1"    area = areaTriangle(a, b, c)    print("Area of triangle with sides {}, {}, {} is: {:.2f}".format(a, b, c, area))if __name__ == "__main__":    main()
