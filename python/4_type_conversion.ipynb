# %%
print("Type Conversion Program")print("=" * 30)num_int = int(input("Enter an integer: "))num_float = float(input("Enter a float: "))num_str = input("Enter a string: ")print("\nOriginal inputs:")print("Integer: {}, Type: {}".format(num_int, type(num_int)))print("Float: {}, Type: {}".format(num_float, type(num_float)))print("String: {}, Type: {}".format(num_str, type(num_str)))print("\nConversions:")print("{} -> Float: {}".format(num_int, float(num_int)))print("{} -> String: {}".format(num_int, str(num_int)))print("{} -> Int: {}".format(num_float, int(num_float)))print("{} -> String: {}".format(num_float, str(num_float)))if num_str.isdigit():    print("'{}' -> Int: {}".format(num_str, int(num_str)))print("\n{} in Hex: {}".format(num_int, hex(num_int)))print("{} in Octal: {}".format(num_int, oct(num_int)))print("{} in Binary: {}".format(num_int, bin(num_int)))
