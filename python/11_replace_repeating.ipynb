# %%
def replace_repeating_chars(s):    result = ""    prev = ""    for char in s:        if char == prev:            result += "*"        else:            result += char        prev = char    return resulttest_strings = ["balloon", "hello", "bookkeeper", "committee"]for s in test_strings:    print("'{}' -> '{}'".format(s, replace_repeating_chars(s)))user_str = input("\nEnter a string: ")print("Result: {}".format(replace_repeating_chars(user_str)))
