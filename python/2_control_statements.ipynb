# %%
num = 10if num > 0:    print("Positive number")elif num == 0:    print("Zero")else:    print("Negative number")print("\nFor loop:")for i in range(1, 6):    print("i =", i)print("\nWhile loop:")count = 0while count < 5:    print("count =", count)    count += 1print("\nNested loops:")for i in range(1, 4):    for j in range(1, 4):        print("i={}, j={}".format(i, j))print("\nBreak statement:")for i in range(1, 10):    if i == 5:        break    print("i =", i)print("\nContinue statement:")for i in range(1, 6):    if i == 3:        continue    print("i =", i)print("\nPass statement:")for i in range(1, 4):    if i == 2:        pass    print("Processing i =", i)status = 404print("\nMatch-case:")match status:    case 200:        print("OK")    case 404:        print("Not Found")    case _:        print("Unknown")
