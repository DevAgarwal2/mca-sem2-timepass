# %%
print("Membership Operators:")list1 = [1, 2, 3, 4, 5]tuple1 = (10, 20, 30)str1 = "Python"print("list1 = {}".format(list1))print("3 in list1: {}".format(3 in list1))print("10 in list1: {}".format(10 in list1))print("3 not in list1: {}".format(3 not in list1))print("\ntuple1 = {}".format(tuple1))print("20 in tuple1: {}".format(20 in tuple1))print("\nstr1 = '{}'".format(str1))print("'thon' in str1: {}".format('thon' in str1))print("'java' in str1: {}".format('java' in str1))print("\nIdentity Operators:")a = [1, 2, 3]b = ac = [1, 2, 3]print("a = {}".format(a))print("b = a")print("c = [1, 2, 3]")print("a is b: {}".format(a is b))print("a is c: {}".format(a is c))print("a is not c: {}".format(a is not c))x = Noney = Noneprint("\nx = None, y = None")print("x is None: {}".format(x is None))print("x is y: {}".format(x is y))print("\nBitwise Operators:")a = 5b = 3print("a = {} (binary: {})".format(a, bin(a)))print("b = {} (binary: {})".format(b, bin(b)))print("a & b = {} (binary: {})".format(a & b, bin(a & b)))print("a | b = {} (binary: {})".format(a | b, bin(a | b)))print("a ^ b = {} (binary: {})".format(a ^ b, bin(a ^ b)))print("~a = {}".format(~a))print("a << 2 = {}".format(a << 2))print("a >> 1 = {}".format(a >> 1))
