# %%
roll_no = input("Enter Roll Number: ")name = input("Enter Student Name: ")print("\nEnter marks for 5 courses (out of 100):")marks = []for i in range(1, 6):    m = float(input("Course {} marks: ".format(i)))    marks.append(m)total = sum(marks)percentage = (total / 500) * 100if percentage >= 90:    grade = "A+"elif percentage >= 80:    grade = "A"elif percentage >= 70:    grade = "B+"elif percentage >= 60:    grade = "B"elif percentage >= 50:    grade = "C"else:    grade = "F"print("\n" + "=" * 40)print("STUDENT GRADE REPORT")print("=" * 40)print("Roll No: {}".format(roll_no))print("Name: {}".format(name))print("-" * 40)print("Marks in 5 courses:")for i, m in enumerate(marks, 1):    print("  Course {}: {}".format(i, m))print("-" * 40)print("Total Marks: {:.2f} / 500".format(total))print("Percentage: {:.2f}%".format(percentage))print("Grade: {}".format(grade))print("=" * 40)
