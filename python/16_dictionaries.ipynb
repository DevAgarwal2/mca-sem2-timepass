# %%
d = {    "name": "John",    "age": 25,    "city": "New York",    "marks": [85, 90, 78]}print("Dictionary:", d)print("Name:", d["name"])print("Age:", d.get("age"))print("City:", d.get("city", "Unknown"))print("\nAll keys:", list(d.keys()))print("All values:", list(d.values()))print("All items:", list(d.items()))d["email"] = "john@email.com"d["age"] = 26print("\nAfter updates:", d)d.pop("city")print("After pop:", d)d.popitem()print("After popitem:", d)print("\nNested dictionary:")student = {    "name": "Alice",    "details": {        "age": 20,        "branch": "CS"    }}print(student["details"]["branch"])print("\nDictionary comprehension:")squares = {x: x*x for x in range(6)}print(squares)
