# %%
def are_coprimes(a, b):    while b:        a, b = b, a % b    return a == 1num1 = int(input("Enter first number: "))num2 = int(input("Enter second number: "))if are_coprimes(num1, num2):    print("{} and {} are coprime numbers.".format(num1, num2))else:    print("{} and {} are not coprime numbers.".format(num1, num2))print("\nExamples:")pairs = [(12, 15), (14, 15), (8, 9), (18, 24)]for a, b in pairs:    print("{} and {}: {}".format(a, b, are_coprimes(a, b)))
