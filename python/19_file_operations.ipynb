# %%
f = open("sample.txt", "w")f.write("Hello, this is a sample file.\n")f.write("This is second line.\n")f.write("This is third line.\n")f.close()print("File written successfully.")print("\nReading file:")f = open("sample.txt", "r")content = f.read()print(content)f.close()print("\nReading line by line:")f = open("sample.txt", "r")for line in f:    print(line.strip())f.close()print("\nUsing with statement:")with open("sample.txt", "r") as f:    data = f.readlines()    print("Lines:", len(data))with open("sample.txt", "a") as f:    f.write("Appended line.\n")print("\nAfter appending:")with open("sample.txt", "r") as f:    print(f.read())
