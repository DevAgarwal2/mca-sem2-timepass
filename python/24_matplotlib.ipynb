# %%
import matplotlib.pyplot as pltimport numpy as npx = np.array([1, 2, 3, 4, 5])y = np.array([2, 4, 6, 8, 10])plt.figure(figsize=(12, 8))plt.subplot(2, 2, 1)plt.plot(x, y, marker='o', color='blue', linestyle='-')plt.title('Line Plot')plt.xlabel('X')plt.ylabel('Y')plt.grid(True)plt.subplot(2, 2, 2)categories = ['A', 'B', 'C', 'D', 'E']values = [5, 7, 3, 8, 6]plt.bar(categories, values, color='green')plt.title('Bar Plot')plt.xlabel('Category')plt.ylabel('Value')plt.subplot(2, 2, 3)data = [22, 25, 28, 28, 29, 30, 31, 32, 35, 36, 40, 42]plt.hist(data, bins=8, color='orange', edgecolor='black')plt.title('Histogram')plt.xlabel('Value')plt.ylabel('Frequency')plt.subplot(2, 2, 4)x_scatter = np.random.rand(50)y_scatter = np.random.rand(50)plt.scatter(x_scatter, y_scatter, color='red', alpha=0.7)plt.title('Scatter Plot')plt.xlabel('X')plt.ylabel('Y')plt.tight_layout()plt.savefig('matplotlib_plots.png')plt.show()print("Plots saved to matplotlib_plots.png")print("\nEquation plotting:")x_eq = np.linspace(0, 2*np.pi, 100)y_sin = np.sin(x_eq)y_cos = np.cos(x_eq)plt.figure()plt.plot(x_eq, y_sin, label='sin(x)')plt.plot(x_eq, y_cos, label='cos(x)')plt.title('Sin and Cos waves')plt.xlabel('x')plt.ylabel('y')plt.legend()plt.grid(True)plt.savefig('equation_plot.png')plt.show()print("Equation plot saved to equation_plot.png")
