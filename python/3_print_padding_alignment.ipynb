# %%
print("Padding and Alignment:")print("{:>10}".format("Hello"))print("{:<10}".format("Hello"))print("{:^10}".format("Hello"))print("{:^20}".format("Python"))print("{:->10}".format("Hello"))print("{:*^10}".format("Hello"))print("\nNumber formatting:")print("{:.2f}".format(3.14159))print("{:10d}".format(42))print("{:010d}".format(42))print("{:+d}".format(42))print("{:=+10d}".format(42))print("\nMutable object (list):")list1 = [1, 2, 3]list2 = list1list2.append(4)print("list1:", list1)print("list2:", list2)print("\nImmutable object (string):")str1 = "Hello"str2 = str1str2 = str2 + " World"print("str1:", str1)print("str2:", str2)tup = (1, 2, 3)print("\nImmutable tuple:")print("tup:", tup)
