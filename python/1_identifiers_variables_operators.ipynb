# %%
counter = 100miles = 1000.0name = "Python"is_active = TruePI = 3.14159GRAVITY = 9.8print("Variables:")print("counter =", counter)print("miles =", miles)print("name =", name)print("is_active =", is_active)print("\nConstants:")print("PI =", PI)print("GRAVITY =", GRAVITY)var_name = "valid identifier"_private_var = 10CamelCase = 20PascalCase = 30import keywordprint("\nPython keywords:", keyword.kwlist)a = 10b = 3print("\nArithmetic Operators:")print("a =", a, ", b =", b)print("a + b =", a + b)print("a - b =", a - b)print("a * b =", a * b)print("a / b =", a / b)print("a // b =", a // b)print("a % b =", a % b)print("a ** b =", a ** b)print("\nComparison Operators:")print("a == b:", a == b)print("a != b:", a != b)print("a > b:", a > b)print("a < b:", a < b)print("a >= b:", a >= b)print("a <= b:", a <= b)print("\nLogical Operators:")x = Truey = Falseprint("x =", x, ", y =", y)print("x and y:", x and y)print("x or y:", x or y)print("not x:", not x)print("\nAssignment Operators:")c = 5print("c =", c)c += 3print("c += 3:", c)c -= 2print("c -= 2:", c)c *= 2print("c *= 2:", c)c /= 4print("c /= 4:", c)
