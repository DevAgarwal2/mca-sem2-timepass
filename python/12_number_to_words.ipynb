# %%
def number_to_words(n):    digit_words = {        '0': 'Zero', '1': 'One', '2': 'Two', '3': 'Three', '4': 'Four',        '5': 'Five', '6': 'Six', '7': 'Seven', '8': 'Eight', '9': 'Nine'    }    result = []    for digit in str(n):        result.append(digit_words[digit])    return " ".join(result)num = int(input("Enter a number: "))print("Result: {}".format(number_to_words(num)))print("\nExamples:")for n in [452, 123, 987]:    print("{} -> {}".format(n, number_to_words(n)))
