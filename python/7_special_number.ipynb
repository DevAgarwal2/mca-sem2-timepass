# %%
def is_special_number(n):    num = n    sum_digits = 0    prod_digits = 1    while n > 0:        digit = n % 10        sum_digits += digit        prod_digits *= digit        n //= 10    return sum_digits + prod_digits == numnum = int(input("Enter a number: "))if is_special_number(num):    print("{} is a special number.".format(num))else:    print("{} is not a special number.".format(num))print("\nExamples:")for n in [59, 39, 12, 10]:    print("{}: {}".format(n, is_special_number(n)))
