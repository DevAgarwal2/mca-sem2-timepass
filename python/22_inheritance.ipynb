# %%
class Animal:    def __init__(self, name):        self.name = name    def speak(self):        print("Some sound")class Dog(Animal):    def speak(self):        print("Woof!")class Cat(Animal):    def speak(self):        print("Meow!")class Bird(Animal):    def speak(self):        print("Chirp!")print("Single Inheritance:")dog = Dog("Buddy")dog.speak()print("\nMultiple inheritance simulation:")class Pet:    def __init__(self, owner):        self.owner = ownerclass FriendlyDog(Dog, Pet):    def __init__(self, name, owner):        Dog.__init__(self, name)        Pet.__init__(self, owner)    def play(self):        print("{} plays with {}".format(self.name, self.owner))fdog = FriendlyDog("Max", "John")fdog.speak()fdog.play()print("\nMethod overriding:")animals = [Dog("Rex"), Cat("Whiskers"), Bird("Tweety")]for animal in animals:    animal.speak()print("\nUsing super():")class BetterDog(Dog):    def __init__(self, name, breed):        super().__init__(name)        self.breed = breed    def speak(self):        super().speak()        print("Breed: {}".format(self.breed))bd = BetterDog("Rocky", "Labrador")bd.speak()
